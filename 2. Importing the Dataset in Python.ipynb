# %% [markdown]
# # Import Data set in to Python

# %% [markdown]
# ## 1. Import CSV File

# %%
# Import Pandas Library

import pandas as pd

# %%
bank = pd.read_csv("C:/Users/Hiren Kakkad/Desktop/Python Project/bankwise.csv")
bank.head()

# %%
# Use separator argument when there is different separator

bank = pd.read_csv("C:/Users/Hiren Kakkad/Desktop/Python Project/bankwise.csv", sep = ",")
bank.head()
# Out:
#          Date      USD      GBP     EURO    YEN
# 0  22/03/2016  66.5411  95.7526  74.8987  59.37
# 1  21/03/2016  66.5040  95.8722  74.9168  59.66
# 2  18/03/2016  66.6088  96.3230  75.3012  59.87
# 3  17/03/2016  66.8806  95.1644  75.0735  59.59
# 4  16/03/2016  67.3680  95.1708  74.7583  59.40

# %%
# Limit no. of rows to be imported

bank = pd.read_csv("C:/Users/Hiren Kakkad/Desktop/Python Project/bankwise.csv", nrows = 10)
bank
# Out:
#          Date      USD      GBP     EURO    YEN
# 0  22/03/2016  66.5411  95.7526  74.8987  59.37
# 1  21/03/2016  66.5040  95.8722  74.9168  59.66
# 2  18/03/2016  66.6088  96.3230  75.3012  59.87
# 3  17/03/2016  66.8806  95.1644  75.0735  59.59
# 4  16/03/2016  67.3680  95.1708  74.7583  59.40
# 5  15/03/2016  67.2290  95.9223  74.6444  59.31
# 6  14/03/2016  67.0230  96.3389  74.8044  58.90
# 7  11/03/2016  67.0868  95.7530  74.9427  59.13
# 8  10/03/2016  67.0510  95.2258  73.6220  58.99
# 9  09/03/2016  67.4632  95.6965  74.0611  59.92

# %%
# When there is no header to the file

bank = pd.read_csv("C:/Users/Hiren Kakkad/Desktop/Python Project/bankwise.csv", header = None)
bank.head()
# Out:
#             0        1        2        3      4
# 0        Date      USD      GBP     EURO    YEN
# 1  22/03/2016  66.5411  95.7526  74.8987  59.37
# 2  21/03/2016   66.504  95.8722  74.9168  59.66
# 3  18/03/2016  66.6088   96.323  75.3012  59.87
# 4  17/03/2016  66.8806  95.1644  75.0735  59.59

# %%
# Change the name of the Header Column

bank = pd.read_csv("C:/Users/Hiren Kakkad/Desktop/Python Project/bankwise.csv", header = None, names = ["Column 1","Column 2", "Column 3", "Column 4", "Column 5"])
bank.head()
# Out:
#      Column 1 Column 2 Column 3 Column 4 Column 5
# 0        Date      USD      GBP     EURO      YEN
# 1  22/03/2016  66.5411  95.7526  74.8987    59.37
# 2  21/03/2016   66.504  95.8722  74.9168    59.66
# 3  18/03/2016  66.6088   96.323  75.3012    59.87
# 4  17/03/2016  66.8806  95.1644  75.0735    59.59

# %%
# Specify Column names from separate object

col_names = ["Date", "Price 1", "Price 2", "Price 3", "Price 4"]
bank = pd.read_csv("C:/Users/Hiren Kakkad/Desktop/Python Project/bankwise.csv", header = None, names = col_names)
bank.head()
# Out:
#          Date  Price 1  Price 2  Price 3 Price 4
# 0        Date      USD      GBP     EURO     YEN
# 1  22/03/2016  66.5411  95.7526  74.8987   59.37
# 2  21/03/2016   66.504  95.8722  74.9168   59.66
# 3  18/03/2016  66.6088   96.323  75.3012   59.87
# 4  17/03/2016  66.8806  95.1644  75.0735   59.59

# %%
# Import file by location variable

location = "C:/Users/Hiren Kakkad/Desktop/Python Project/bankwise.csv"

bank = pd.read_csv(location)
bank.head()
# Out:
#          Date      USD      GBP     EURO    YEN
# 0  22/03/2016  66.5411  95.7526  74.8987  59.37
# 1  21/03/2016  66.5040  95.8722  74.9168  59.66
# 2  18/03/2016  66.6088  96.3230  75.3012  59.87
# 3  17/03/2016  66.8806  95.1644  75.0735  59.59
# 4  16/03/2016  67.3680  95.1708  74.7583  59.40

# %% [markdown]
# ## 2. Import Excel File

# %%
import pandas as pd

# %%
uk = pd.read_excel("C:/Users/Hiren Kakkad/Desktop/Python Project/uk.xlsx")
uk.head()
# Out:
#     quarter     GDP     PDI     PCE  Profits  Divinded
# 0    1970-I  2872.8  1990.5  1800.5     44.7      24.5
# 1   1970-II  2860.3  2020.1  1807.5     44.4      23.9
# 2  1970-III  2896.6  2045.3  1824.7     44.9      23.3
# 3   1970-IV  2873.7  2045.2  1821.2     42.1      23.1
# 4    1971-I  2942.9  2073.9  1849.9     48.8      23.8

# %%
# To Fetch a Column from a Dataset

uk.GDP

# %%
# To Fetch a Column from a Dataset

uk["GDP"]

# %%
# To Add Two Columns of a Dataset

uk.GDP + uk.PDI

# %%
# To get Number of observations in a data

uk.GDP.size

# %%
# To Get an Array Output

uk.GDP.values
# Out:
# array([2872.8, 2860.3, 2896.6, 2873.7, 2942.9, 2947.4, 2966. , 2980.8,
#        3037.3, 3089.7, 3125.8, 3175.5, 3253.3, 3267.6, 3264.3, 3289.1,
#        3259.4, 3267.6, 3239.1, 3226.4, 3154. , 3190.4, 3249.9, 3292.5,
#        3356.7, 3369.2, 3381. , 3416.3, 3466.4, 3525. , 3574.4, 3567.2,
#        3591.8, 3707. , 3735.6, 3779.6, 3780.8, 3784.3, 3807.5, 3814.6,
#        3830.8, 3732.6, 3733.5, 3808.5, 3860.5, 3844.4, 3864.5, 3803.1,
#        3756.1, 3771.1, 3754.4, 3759.6, 3783.3, 3886.5, 3944.4, 4012.1,
#        4089.5, 4144. , 4166.4, 4194.2, 4221.8, 4254.8, 4309. , 4333.5,
#        4390.5, 4387.7, 4412.6, 4427.1, 4460. , 4515.3, 4559.3, 4625.5,
#        4655.3, 4704.8, 4734.3, 4779.7, 4809.8, 4832.4, 4845.6, 4859.7,
#        4880.8, 4900.3, 4903.3, 4855.1, 4824. , 4840.7, 4862.7, 4868. ])

# %% [markdown]
# ## 3. Import Data from Text

# %%
import pandas as pd

# %%
tabdata = pd.read_table("C:/Users/Neerav/Hiren Jupyter/salary.txt")
tabdata
# Out:
#     Sr.no.  salary     region
# 0        1    4.05      South
# 1        2    4.15      South
# 2        3    4.00      South
# 3        4    4.10      South
# 4        5    4.15      South
# 5        6    5.10  Northeast
# 6        7    4.95  Northeast
# 7        8    4.90  Northeast
# 8        9    4.80  Northeast
# 9       10    4.95  Northeast
# 10      11    4.55       West
# 11      12    4.35       West
# 12      13    4.50       West
# 13      14    4.65       West
# 14      15    4.60       West

# %% [markdown]
# ## 4. Import Data from HTML

# %%
# !pip install html5lib

# %%
import pandas as pd
from pandas import read_html
import html5lib

# %%
url = "https://www.moneycontrol.com/mutual-funds/best-funds/equity.html"

# %%
mutual_fund = pd.io.html.read_html(url)
mutual_fund
# Out:
# [                                          Scheme Name  Crisil Rank  AuM (Cr)  \
#  0   IIFL Focused Equity Fund - Direct Plan - Growt...            5    446.15
#  1       IIFL Focused Equity Fund - GrowthFocused Fund            5    446.15
#  2   Axis Bluechip Fund - Direct Plan - GrowthLarge...            5   8749.21
#  3   Axis Small Cap Fund - Direct Plan - GrowthSmal...            5   1199.83
#  4          Axis Small Cap Fund - GrowthSmall Cap Fund            5   1199.83
#  5           Axis Bluechip Fund - GrowthLarge Cap Fund            5   8749.21
#  6   BNP Paribas Large Cap Fund - Direct Plan - Gro...            5    807.89
#  7   DSP Equity Fund - Direct Plan - GrowthMulti Ca...            5   2888.35
#  8   JM Multicap Fund - (Direct) - GrowthMulti Cap ...            5    142.54
#  9   BNP Paribas Large Cap Fund - GrowthLarge Cap Fund            5    807.89
#  10  Mirae Asset Emerging Bluechip Fund - Direct Pl...            5   8868.42
# ...

# %%
mf_data = mutual_fund[0]

# %%
mf_data.head()
# Out:
#                                          Scheme Name  Crisil Rank  AuM (Cr)  \
# 0  IIFL Focused Equity Fund - Direct Plan - Growt...            5    446.15
# 1      IIFL Focused Equity Fund - GrowthFocused Fund            5    446.15
# 2  Axis Bluechip Fund - Direct Plan - GrowthLarge...            5   8749.21
# 3  Axis Small Cap Fund - Direct Plan - GrowthSmal...            5   1199.83
# 4         Axis Small Cap Fund - GrowthSmall Cap Fund            5   1199.83
#
#        1W     1M      3M     6M     YTD      1Y      2Y      3Y      5Y 10Y
# 0   0.76%  4.51%  12.61%  8.23%  14.19%  29.97%   9.62%  15.87%  12.21%   -
# 1   0.73%  4.37%  12.19%  7.41%  13.05%  28.04%   8.01%  14.20%  10.80%   -
# 2   1.14%  2.62%   9.52%  8.35%  13.41%  22.04%  14.93%  21.15%  11.37%   -
# 3  -0.62%  0.54%   8.59%  9.19%  14.26%  22.00%   6.95%  14.98%  12.75%   -
# 4  -0.63%  0.42%   8.19%  8.49%  13.31%  20.55%   5.74%  13.68%  11.51%   -

# %%
## 5. Import from SPSS file

# %%
spss_data = pd.read_spss("C:/Users/Neerav/Hiren Jupyter/ANC study.sav")
spss_data.head()
# Out:
#    sr.No Hospital   Age region        ANC    Hb Folic_Acid Iron Calcium  \
# 0    1.0   Public  26.0  Urban    Regular  11.6        YES  YES     YES
# 1    2.0   Public  21.0  Urban    Regular   6.7        YES  YES     YES
# 2    3.0   Public  22.0  Urban    Regular  11.6        YES  YES     YES
# 3    4.0   Public  22.0  Urban    Regular  10.8         NO  YES     YES
# 4    5.0   Public  22.0  Rural  Irregular   9.5         NO  YES     YES
#
#   Multi_Vitamin Dietary_Supplement Anti_emetic Antacid Analgesic  \
# 0           YES                 NO          NO     YES        NO
# 1            NO                 NO         YES      NO        NO
# 2           YES                YES         YES     YES       YES
# 3            NO                YES          NO     YES        NO
# 4            NO                 NO          NO      NO        NO
#
#   Uterinerelaxant Anti_Hypertensives Anti_Biotic Anti_Fungal Anti_histaminic
# ...
